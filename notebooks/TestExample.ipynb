# %%
import DataLoader
import importlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import CoverageHelper
importlib.reload(DataLoader)

# %matplotlib inline
stat_trans_act_graph_df = DataLoader.load_csv_stat_graph("-act-transitive")
# Out:
# Number of apps:
# 376
# Total entries:
# 36613
# Number of apps:
# 376
# Total entries:
# 36613
# Total entries:
# 36613

# %%
stat_trans_act_graph_df.head()
# Out:
#                   package                                source  \
# 0  bth.studio.quickcharge  bth.studio.quickcharge.SaverActivity
# 1  bth.studio.quickcharge  bth.studio.quickcharge.SaverActivity
# 2  bth.studio.quickcharge  bth.studio.quickcharge.SaverActivity
# 3  bth.studio.quickcharge  bth.studio.quickcharge.SaverActivity
# 4  bth.studio.quickcharge     bth.studio.quickcharge.TabManager
#
#                                            target   method  \
# 0    bth.studio.quickcharge.saver.DialogSleepMode  onClick
# 1  bth.studio.quickcharge.saver.Dialog_SavingMode  onClick
# 2   bth.studio.quickcharge.saver.DialogCustomMode  onClick
# 3   bth.studio.quickcharge.saver.DialogCustomMode  onClick
# 4          bth.studio.quickcharge.ActivityService        f
#
#                           widget                     app
# 0                            NaN  bth.studio.quickcharge
# 1                            NaN  bth.studio.quickcharge
# ...

# %%
temp = stat_trans_act_graph_df[["app", "method", "widget"]]
stat_trans_act_graph_df.groupby(["app"]).head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>package</th>
#       <th>source</th>
#       <th>target</th>
#       <th>method</th>
#       <th>widget</th>
#       <th>app</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>com.udn.howtodraw.undertale</td>
#       <td>com.example.drawingfun.ab</td>
#       <td>com.example.drawingfun.DrawingActivity</td>
#       <td>onItemClick</td>
#       <td>android.widget.GridView</td>
#       <td>com.udn.howtodraw.undertale</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>com.udn.howtodraw.undertale</td>
#       <td>com.example.drawingfun.StartActivity</td>
# ...
